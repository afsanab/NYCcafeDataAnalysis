# %% [markdown]
# # NYC Restaurant Inspection Analytics
#
# Analysis of NYC restaurant inspection data, focusing on coffee and tea establishments.

# %%
import pandas as pd

# Load NYC restaurant inspection data
inspection_file = r"c:\Users\Afsana\Documents\TheDataSchoolApplication\NYCcafeDataAnalysis\data\DOHMH_New_York_City_Restaurant_Inspection_Results_20260313.csv"

try:
    # Read the CSV file (already filtered for coffee/tea)
    df = pd.read_csv(inspection_file)

    print(f"✓ Loaded {len(df)} coffee/tea establishments")

    # Display first few rows
    print("\nFirst 5 Coffee/Tea Establishments:")
    print(df.head()[['DBA', 'BORO', 'CUISINE DESCRIPTION', 'SCORE', 'GRADE', 'INSPECTION DATE']])

except FileNotFoundError:
    print(f"❌ File not found: {inspection_file}")
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# ✓ Loaded 21125 coffee/tea establishments
#
# First 5 Coffee/Tea Establishments:
#                   DBA       BORO CUISINE DESCRIPTION  SCORE GRADE  \
# 0              DUNKIN     Queens          Coffee/Tea   21.0   NaN
# 1          WORLD BEAN     Queens          Coffee/Tea   11.0     A
# 2          PARK & BEL          0          Coffee/Tea   70.0     N
# 3           STARBUCKS  Manhattan          Coffee/Tea    NaN   NaN
# 4  BLUE BOTTLE COFFEE  Manhattan          Coffee/Tea    0.0   NaN
#
#   INSPECTION DATE
# 0      06/02/2022
# 1      01/18/2018
# 2      01/20/2026
# 3      09/01/2022
# 4      01/30/2025

# %%
import pandas as pd
df = pd.read_csv("data/DOHMH_New_York_City_Restaurant_Inspection_Results_20260313.csv")
print(df.columns.tolist())
# Out:
# ['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE', 'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE', 'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE', 'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude', 'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL', 'NTA', 'Location']
